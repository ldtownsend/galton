# %%
# !python scripts/get_accuweather_data.py
# Out:
# Saved Austin: data/staging/accuweather_forecasts/accuweather_12h_austin_20251213_034707.parquet
# Saved Chicago: data/staging/accuweather_forecasts/accuweather_12h_chicago_20251213_034707.parquet
# Saved Denver: data/staging/accuweather_forecasts/accuweather_12h_denver_20251213_034707.parquet
# Saved Houston: data/staging/accuweather_forecasts/accuweather_12h_houston_20251213_034707.parquet
# Saved Los Angeles: data/staging/accuweather_forecasts/accuweather_12h_los_angeles_20251213_034707.parquet
# Saved Miami: data/staging/accuweather_forecasts/accuweather_12h_miami_20251213_034707.parquet
# Saved New York: data/staging/accuweather_forecasts/accuweather_12h_new_york_20251213_034707.parquet
# Saved Philadelphia: data/staging/accuweather_forecasts/accuweather_12h_philadelphia_20251213_034707.parquet

# %%
# !python scripts/get_nws_observations.py
# Out:
# NWS History shape: (573, 8) -- 2025-12-12 21:47:37.090696-06:00

# %%
# !python scripts/get_openmeteo_data.py
