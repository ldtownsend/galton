# %%
import pandas as pd

# %% [markdown]
# # Openmeteo Forecasts

# %%
df = pd.read_parquet("data/staging/openmeteo_forecasts/multi_model_forecasts--2025-12-07T20_48_49.017353_06_00.parquet")

# %%
df
# Out:
#                forecast_date  temperature_2m          city  \
# 0  2025-12-07 18:00:00-06:00       54.633202        Austin
# 1  2025-12-07 19:00:00-06:00       51.663200        Austin
# 2  2025-12-07 20:00:00-06:00       50.853199        Austin
# 3  2025-12-07 21:00:00-06:00       50.403198        Austin
# 4  2025-12-07 22:00:00-06:00       49.143200        Austin
# ..                       ...             ...           ...
# 67 2025-12-10 13:00:00-06:00       35.893402  Philadelphia
# 68 2025-12-10 14:00:00-06:00       37.243401  Philadelphia
# 69 2025-12-10 15:00:00-06:00       38.413399  Philadelphia
# 70 2025-12-10 16:00:00-06:00       39.133400  Philadelphia
# 71 2025-12-10 17:00:00-06:00       39.583401  Philadelphia
#
#              model_timestamp                current_timestamp  \
# 0  2025-12-07 20:45:00-06:00 2025-12-07 20:48:48.936755-06:00
# 1  2025-12-07 20:45:00-06:00 2025-12-07 20:48:48.936755-06:00
# 2  2025-12-07 20:45:00-06:00 2025-12-07 20:48:48.936755-06:00
# ...

# %%
del df

# %% [markdown]
# # Accuweather Forecasts

# %%
df = pd.read_parquet(
    "data/staging/accuweather_forecasts/accuweather_12h_new_york_20251208_031733.parquet"
)

# %%
df.head()
# Out:
#                    datetime  EpochDateTime  WeatherIcon        phrase  \
# 0 2025-12-07 23:00:00-05:00     1765166400           34  Mostly clear
# 1 2025-12-08 00:00:00-05:00     1765170000           34  Mostly clear
# 2 2025-12-08 01:00:00-05:00     1765173600           34  Mostly clear
# 3 2025-12-08 02:00:00-05:00     1765177200           34  Mostly clear
# 4 2025-12-08 03:00:00-05:00     1765180800           34  Mostly clear
#
#    has_precip  IsDaylight  rh  IndoorRelativeHumidity  uv_index  UVIndexFloat  \
# 0       False       False  59                      34         0           0.0
# 1       False       False  60                      35         0           0.0
# 2       False       False  60                      34         0           0.0
# 3       False       False  56                      32         0           0.0
# 4       False       False  52                      30         0           0.0
#
# ...

# %%
del df

# %% [markdown]
# # NWS Observations

# %%
df = pd.read_parquet(
    "data/staging/nws_observations/nws_observations--2025-12-07T21_50_14.035655_06_00.parquet"
)

# %%
df
# Out:
#     date   time         wind       weather   air 6_hour_max  \
# 0     07  20:53        N  10          Fair    50       None
# 1     07  19:53        N  13  A Few Clouds    50       None
# 2     07  18:53         N  9  A Few Clouds  46.9       None
# 3     07  17:53        N  12  A Few Clouds    54         73
# 4     07  16:53        N  16  A Few Clouds    57       None
# ..   ...    ...          ...           ...   ...        ...
# 570   05  02:54         N  9      Overcast    27       None
# 571   05  01:54        N  13      Overcast    27       None
# 572   05  00:54  N  15  G 23      Overcast    28       37.9
# 573   04  23:54  N  16  G 25      Overcast  28.9       None
# 574   04  22:54  N  15  G 24      Overcast  30.9       None
#
#                            timestamp          city
# 0   2025-12-07 21:50:13.082898-06:00        Austin
# 1   2025-12-07 21:50:13.082898-06:00        Austin
# 2   2025-12-07 21:50:13.082898-06:00        Austin
# ...

# %%
del df
